# %%
# !pip install requests
# !pip install bs4
# !pip install opencv-python
# !pip install opencv-contrib-python
# !pip install matplotlib
# !pip install pandas
# !pip install tqdm
# !pip install black 
# !pip install flakes8 
# !pip install isort
# !pip install argparse

# %%
import logging

logging.basicConfig(level=logging.DEBUG)
logger = logging.getLogger()

# %%
from typing import Union
from pathlib import Path

def create_file_url(subject_id: str, study_id: str, image_id: str) -> str:
    """
    Create a URL to download a file from PhysioNet.
    """
    return f"https://www.physionet.org//mimic-cxr-jpg/2.0.0/files/p{subject_id[0:2]}/p{subject_id}/s{study_id}/{image_id}.jpg"

def create_saved_path(root_dir: Union[str, Path], subject_id: str, study_id: str, image_id: str) -> Path:
    """
    Create a path to save a file from PhysioNet.
    """
    return Path(root_dir) / f"p{subject_id[0:2]}/p{subject_id}/s{study_id}/{image_id}.jpg"

create_file_url('10000032','50414267', '02aa804e-bde0afdd-112c0b34-7bc16630-4e384014')
# Out:
# 'https://www.physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10000032/s50414267/02aa804e-bde0afdd-112c0b34-7bc16630-4e384014.jpg'

# %%
import os
from typing import List, Tuple
from requests import Session

import cv2
import numpy as np

from tqdm import tqdm

root_dir = "./cxr_dataset/"

def transform_image_from_bytes(image: bytes) -> np.ndarray:
    """
    Transform an image from bytes to a NumPy array.
    """
    nparr = np.frombuffer(image, np.uint8)
    img = cv2.imdecode(nparr, cv2.IMREAD_COLOR)
    height, width = img.shape[:2]

    # Calculate the new dimensions
    new_width = int(width / 4)
    new_height = int(height / 4)

    # Resize the image
    img = cv2.resize(img, (new_width, new_height), interpolation = cv2.INTER_AREA)
    return img

def download_images(session: Session,images_info: List[Tuple[str, str, str]]) -> List[Tuple[str, str, str]]:
    """
    Download an image from PhysioNet.
    """
    failed_download = []
    
    i = 0

    for image_info in tqdm(images_info):
        subject_id, study_id, image_id = image_info
        url = create_file_url(subject_id, study_id, image_id)
        path = create_saved_path(root_dir, subject_id, study_id, image_id)

        os.makedirs(path.parent, exist_ok=True)

        logger.info(f"Start downloading {subject_id} - {study_id} - {image_id}\nFrom URL:{url}\nSaved to: {path}")

        response = session.get(url)
        if response.status_code == 200:
            logger.info(f"Downloaded successfully - Transforming image...")
            img = transform_image_from_bytes(response.content)
            cv2.imwrite(str(path), img)
            logger.info(f"Saved image to {path}")
        else:
            logger.warning(f"Failed to download {subject_id} - {study_id} - {image_id}.")
            failed_download.append(image_info)

        i += 1
        if i == 20:
            break

# %%
import pandas as pd
metadata = './mimic-cxr-2.0.0-metadata.csv'

def get_images_info(metadata_path: str):
    """
    Get a list of images info from the metadata file.
    """
    df = pd.read_csv(metadata_path, dtype=str)
    images_info = df[['subject_id', 'study_id', 'dicom_id']].values.tolist()
    return images_info

# %%
import requests
from bs4 import BeautifulSoup
import requests

import pandas as pd

# URL of the site to login
site_url = 'https://www.physionet.org/login/'
# Your credentials
username = 'phphuc'
password = '@ABCDE12345@'

# Create a session object
session = requests.Session()

# Get login CSRF token
response = session.get(site_url)
soup = BeautifulSoup(response.text, 'html.parser')
csrfmiddlewaretoken = soup.find('input', dict(name='csrfmiddlewaretoken'))['value']

headers = {
    'referer': 'https://www.physionet.org/login/',
}

# Login
payload = {'username': username, 'password': password, 'csrfmiddlewaretoken': csrfmiddlewaretoken, 'next': '/'}
login_response = session.post(site_url, data=payload, headers=headers)

# Check if login was successful
if login_response.status_code == 200:
    logger.debug("Login successful")

    imgs_info = get_images_info(metadata)
    failed_download = download_images(session, imgs_info)
    pd.DataFrame(data=failed_download, columns=['subject_id', 'study_id', 'dicom_id']).to_csv('failed_download.csv', index=False)
else:
    logger.warn("Login failed\n" + login_response.text)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.physionet.org:443
# DEBUG:urllib3.connectionpool:https://www.physionet.org:443 "GET /login/ HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://www.physionet.org:443 "POST /login/ HTTP/1.1" 302 0
# DEBUG:urllib3.connectionpool:https://www.physionet.org:443 "GET / HTTP/1.1" 200 None
# DEBUG:root:Login successful
#   0%|          | 0/377110 [00:00<?, ?it/s]INFO:root:Start downloading 10000032 - 50414267 - 02aa804e-bde0afdd-112c0b34-7bc16630-4e384014
# From URL:https://www.physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10000032/s50414267/02aa804e-bde0afdd-112c0b34-7bc16630-4e384014.jpg
# Saved to: cxr_dataset/p10/p10000032/s50414267/02aa804e-bde0afdd-112c0b34-7bc16630-4e384014.jpg
# DEBUG:urllib3.connectionpool:https://www.physionet.org:443 "GET /files/mimic-cxr-jpg/2.0.0/files/p10/p10000032/s50414267/02aa804e-bde0afdd-112c0b34-7bc16630-4e384014.jpg HTTP/1.1" 200 1430084
# INFO:root:Downloaded successfully - Transforming image...
# INFO:root:Saved image to cxr_dataset/p10/p10000032/s50414267/02aa804e-bde0afdd-112c0b34-7bc16630-4e384014.jpg
#   0%|          | 1/377110 [00:02<249:20:03,  2.38s/it]INFO:root:Start downloading 10000032 - 50414267 - 174413ec-4ec4c1f7-34ea26b7-c5f994f8-79ef1962
# From URL:https://www.physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10000032/s50414267/174413ec-4ec4c1f7-34ea26b7-c5f994f8-79ef1962.jpg
# Saved to: cxr_dataset/p10/p10000032/s50414267/174413ec-4ec4c1f7-34ea26b7-c5f994f8-79ef1962.jpg
# DEBUG:urllib3.connectionpool:https://www.physionet.org:443 "GET /files/mimic-cxr-jpg/2.0.0/files/p10/p10000032/s50414267/174413ec-4ec4c1f7-34ea26b7-c5f994f8-79ef1962.jpg HTTP/1.1" 200 1202453
# INFO:root:Downloaded successfully - Transforming image...
# INFO:root:Saved image to cxr_dataset/p10/p10000032/s50414267/174413ec-4ec4c1f7-34ea26b7-c5f994f8-79ef1962.jpg
#   0%|          | 2/377110 [00:03<189:39:05,  1.81s/it]INFO:root:Start downloading 10000032 - 53189527 - 2a2277a9-b0ded155-c0de8eb9-c124d10e-82c5caab
# From URL:https://www.physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10000032/s53189527/2a2277a9-b0ded155-c0de8eb9-c124d10e-82c5caab.jpg
# Saved to: cxr_dataset/p10/p10000032/s53189527/2a2277a9-b0ded155-c0de8eb9-c124d10e-82c5caab.jpg
# DEBUG:urllib3.connectionpool:https://www.physionet.org:443 "GET /files/mimic-cxr-jpg/2.0.0/files/p10/p10000032/s53189527/2a2277a9-b0ded155-c0de8eb9-c124d10e-82c5caab.jpg HTTP/1.1" 200 1886228
# INFO:root:Downloaded successfully - Transforming image...
# INFO:root:Saved image to cxr_dataset/p10/p10000032/s53189527/2a2277a9-b0ded155-c0de8eb9-c124d10e-82c5caab.jpg
#   0%|          | 3/377110 [00:05<205:28:26,  1.96s/it]INFO:root:Start downloading 10000032 - 53189527 - e084de3b-be89b11e-20fe3f9f-9c8d8dfe-4cfd202c
# From URL:https://www.physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10000032/s53189527/e084de3b-be89b11e-20fe3f9f-9c8d8dfe-4cfd202c.jpg
# Saved to: cxr_dataset/p10/p10000032/s53189527/e084de3b-be89b11e-20fe3f9f-9c8d8dfe-4cfd202c.jpg
# DEBUG:urllib3.connectionpool:https://www.physionet.org:443 "GET /files/mimic-cxr-jpg/2.0.0/files/p10/p10000032/s53189527/e084de3b-be89b11e-20fe3f9f-9c8d8dfe-4cfd202c.jpg HTTP/1.1" 200 1704899
# INFO:root:Downloaded successfully - Transforming image...
# INFO:root:Saved image to cxr_dataset/p10/p10000032/s53189527/e084de3b-be89b11e-20fe3f9f-9c8d8dfe-4cfd202c.jpg
#   0%|          | 4/377110 [00:07<201:09:32,  1.92s/it]INFO:root:Start downloading 10000032 - 53911762 - 68b5c4b1-227d0485-9cc38c3f-7b84ab51-4b472714
# From URL:https://www.physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10000032/s53911762/68b5c4b1-227d0485-9cc38c3f-7b84ab51-4b472714.jpg
# Saved to: cxr_dataset/p10/p10000032/s53911762/68b5c4b1-227d0485-9cc38c3f-7b84ab51-4b472714.jpg
# DEBUG:urllib3.connectionpool:https://www.physionet.org:443 "GET /files/mimic-cxr-jpg/2.0.0/files/p10/p10000032/s53911762/68b5c4b1-227d0485-9cc38c3f-7b84ab51-4b472714.jpg HTTP/1.1" 200 1400833
# INFO:root:Downloaded successfully - Transforming image...
# INFO:root:Saved image to cxr_dataset/p10/p10000032/s53911762/68b5c4b1-227d0485-9cc38c3f-7b84ab51-4b472714.jpg
#   0%|          | 5/377110 [00:09<194:44:08,  1.86s/it]INFO:root:Start downloading 10000032 - 53911762 - fffabebf-74fd3a1f-673b6b41-96ec0ac9-2ab69818
# From URL:https://www.physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10000032/s53911762/fffabebf-74fd3a1f-673b6b41-96ec0ac9-2ab69818.jpg
# Saved to: cxr_dataset/p10/p10000032/s53911762/fffabebf-74fd3a1f-673b6b41-96ec0ac9-2ab69818.jpg
# DEBUG:urllib3.connectionpool:https://www.physionet.org:443 "GET /files/mimic-cxr-jpg/2.0.0/files/p10/p10000032/s53911762/fffabebf-74fd3a1f-673b6b41-96ec0ac9-2ab69818.jpg HTTP/1.1" 200 1163942
# INFO:root:Downloaded successfully - Transforming image...
# INFO:root:Saved image to cxr_dataset/p10/p10000032/s53911762/fffabebf-74fd3a1f-673b6b41-96ec0ac9-2ab69818.jpg
#   0%|          | 6/377110 [00:11<191:30:20,  1.83s/it]INFO:root:Start downloading 10000032 - 56699142 - ea030e7a-2e3b1346-bc518786-7a8fd698-f673b44c
# From URL:https://www.physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10000032/s56699142/ea030e7a-2e3b1346-bc518786-7a8fd698-f673b44c.jpg
# Saved to: cxr_dataset/p10/p10000032/s56699142/ea030e7a-2e3b1346-bc518786-7a8fd698-f673b44c.jpg
# DEBUG:urllib3.connectionpool:https://www.physionet.org:443 "GET /files/mimic-cxr-jpg/2.0.0/files/p10/p10000032/s56699142/ea030e7a-2e3b1346-bc518786-7a8fd698-f673b44c.jpg HTTP/1.1" 200 1329987
# INFO:root:Downloaded successfully - Transforming image...
# INFO:root:Saved image to cxr_dataset/p10/p10000032/s56699142/ea030e7a-2e3b1346-bc518786-7a8fd698-f673b44c.jpg
#   0%|          | 7/377110 [00:13<200:32:35,  1.91s/it]INFO:root:Start downloading 10000764 - 57375967 - 096052b7-d256dc40-453a102b-fa7d01c6-1b22c6b4
# From URL:https://www.physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10000764/s57375967/096052b7-d256dc40-453a102b-fa7d01c6-1b22c6b4.jpg
# Saved to: cxr_dataset/p10/p10000764/s57375967/096052b7-d256dc40-453a102b-fa7d01c6-1b22c6b4.jpg
# DEBUG:urllib3.connectionpool:https://www.physionet.org:443 "GET /files/mimic-cxr-jpg/2.0.0/files/p10/p10000764/s57375967/096052b7-d256dc40-453a102b-fa7d01c6-1b22c6b4.jpg HTTP/1.1" 200 1707658
# INFO:root:Downloaded successfully - Transforming image...
# INFO:root:Saved image to cxr_dataset/p10/p10000764/s57375967/096052b7-d256dc40-453a102b-fa7d01c6-1b22c6b
# From URL:https://www.physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10000898/s54205396/9e7a6aae-2580e589-6212d336-9813ebbd-a9239a34.jpg
# Saved to: cxr_dataset/p10/p10000898/s54205396/9e7a6aae-2580e589-6212d336-9813ebbd-a9239a34.jpg
# DEBUG:urllib3.connectionpool:https://www.physionet.org:443 "GET /files/mimic-cxr-jpg/2.0.0/files/p10/p10000898/s54205396/9e7a6aae-2580e589-6212d336-9813ebbd-a9239a34.jpg HTTP/1.1" 200 1569254
# INFO:root:Downloaded successfully - Transforming image...
# INFO:root:Saved image to cxr_dataset/p10/p10000898/s54205396/9e7a6aae-2580e589-6212d336-9813ebbd-a9239a34.jpg
#   0%|          | 14/377110 [00:31<243:49:04,  2.33s/it]INFO:root:Start downloading 10000898 - 54205396 - b75df1bd-0f22d631-52d73526-2ae7b85a-d843b39d
# From URL:https://www.physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10000898/s54205396/b75df1bd-0f22d631-52d73526-2ae7b85a-d843b39d.jpg
# Saved to: cxr_dataset/p10/p10000898/s54205396/b75df1bd-0f22d631-52d73526-2ae7b85a-d843b39d.jpg
# DEBUG:urllib3.connectionpool:https://www.physionet.org:443 "GET /files/mimic-cxr-jpg/2.0.0/files/p10/p10000898/s54205396/b75df1bd-0f22d631-52d73526-2ae7b85a-d843b39d.jpg HTTP/1.1" 200 2244882
# INFO:root:Downloaded successfully - Transforming image...
# INFO:root:Saved image to cxr_dataset/p10/p10000898/s54205396/b75df1bd-0f22d631-52d73526-2ae7b85a-d843b39d.jpg
#   0%|          | 15/377110 [00:33<243:35:58,  2.33s/it]INFO:root:Start downloading 10000935 - 50578979 - d0b71acc-b5a62046-bbb5f6b8-7b173b85-65cdf738
# From URL:https://www.physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10000935/s50578979/d0b71acc-b5a62046-bbb5f6b8-7b173b85-65cdf738.jpg
# Saved to: cxr_dataset/p10/p10000935/s50578979/d0b71acc-b5a62046-bbb5f6b8-7b173b85-65cdf738.jpg
# DEBUG:urllib3.connectionpool:https://www.physionet.org:443 "GET /files/mimic-cxr-jpg/2.0.0/files/p10/p10000935/s50578979/d0b71acc-b5a62046-bbb5f6b8-7b173b85-65cdf738.jpg HTTP/1.1" 200 1190078
# INFO:root:Downloaded successfully - Transforming image...
# INFO:root:Saved image to cxr_dataset/p10/p10000935/s50578979/d0b71acc-b5a62046-bbb5f6b8-7b173b85-65cdf738.jpg
#   0%|          | 16/377110 [00:35<209:42:37,  2.00s/it]INFO:root:Start downloading 10000935 - 51178377 - 3be619d1-506a66cf-ff1ab8a1-2efb77bb-fe7d59fc
# From URL:https://www.physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10000935/s51178377/3be619d1-506a66cf-ff1ab8a1-2efb77bb-fe7d59fc.jpg
# Saved to: cxr_dataset/p10/p10000935/s51178377/3be619d1-506a66cf-ff1ab8a1-2efb77bb-fe7d59fc.jpg
# DEBUG:urllib3.connectionpool:https://www.physionet.org:443 "GET /files/mimic-cxr-jpg/2.0.0/files/p10/p10000935/s51178377/3be619d1-506a66cf-ff1ab8a1-2efb77bb-fe7d59fc.jpg HTTP/1.1" 200 1327333
# INFO:root:Downloaded successfully - Transforming image...
# INFO:root:Saved image to cxr_dataset/p10/p10000935/s51178377/3be619d1-506a66cf-ff1ab8a1-2efb77bb-fe7d59fc.jpg
#   0%|          | 17/377110 [00:36<188:35:48,  1.80s/it]INFO:root:Start downloading 10000935 - 51178377 - 9b314ad7-fbcb0422-6db62dfc-732858d0-a5527d8b
# From URL:https://www.physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10000935/s51178377/9b314ad7-fbcb0422-6db62dfc-732858d0-a5527d8b.jpg
# Saved to: cxr_dataset/p10/p10000935/s51178377/9b314ad7-fbcb0422-6db62dfc-732858d0-a5527d8b.jpg
# DEBUG:urllib3.connectionpool:https://www.physionet.org:443 "GET /files/mimic-cxr-jpg/2.0.0/files/p10/p10000935/s51178377/9b314ad7-fbcb0422-6db62dfc-732858d0-a5527d8b.jpg HTTP/1.1" 200 1054830
# INFO:root:Downloaded successfully - Transforming image...
# INFO:root:Saved image to cxr_dataset/p10/p10000935/s51178377/9b314ad7-fbcb0422-6db62dfc-732858d0-a5527d8b.jpg
#   0%|          | 18/377110 [00:37<172:51:57,  1.65s/it]INFO:root:Start downloading 10000935 - 55697293 - 6a5c3985-7764bdd0-ec5a6a74-af78bcaa-4ca33ec3
# From URL:https://www.physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10000935/s55697293/6a5c3985-7764bdd0-ec5a6a74-af78bcaa-4ca33ec3.jpg
# Saved to: cxr_dataset/p10/p10000935/s55697293/6a5c3985-7764bdd0-ec5a6a74-af78bcaa-4ca33ec3.jpg
# DEBUG:urllib3.connectionpool:https://www.physionet.org:443 "GET /files/mimic-cxr-jpg/2.0.0/files/p10/p10000935/s55697293/6a5c3985-7764bdd0-ec5a6a74-af78bcaa-4ca33ec3.jpg HTTP/1.1" 200 995676
# INFO:root:Downloaded successfully - Transforming image...
# INFO:root:Saved image to cxr_dataset/p10/p10000935/s55697293/6a5c3985-7764bdd0-ec5a6a74-af78bcaa-4ca33ec3.jpg
#   0%|          | 19/377110 [00:39<160:27:04,  1.53s/it]INFO:root:Start downloading 10000935 - 55697293 - c50494f1-90e2bff5-e9189550-1a4562fd-6ab5204c
# From URL:https://www.physionet.org/files/mimic-cxr-jpg/2.0.0/files/p10/p10000935/s55697293/c50494f1-90e2bff5-e9189550-1a4562fd-6ab5204c.jpg
# Saved to: cxr_dataset/p10/p10000935/s55697293/c50494f1-90e2bff5-e9189550-1a4562fd-6ab5204c.jpg
# DEBUG:urllib3.connectionpool:https://www.physionet.org:443 "GET /files/mimic-cxr-jpg/2.0.0/files/p10/p10000935/s55697293/c50494f1-90e2bff5-e9189550-1a4562fd-6ab5204c.jpg HTTP/1.1" 200 1147103
# INFO:root:Downloaded successfully - Transforming image...
# INFO:root:Saved image to cxr_dataset/p10/p10000935/s55697293/c50494f1-90e2bff5-e9189550-1a4562fd-6ab5204c.jpg
#   0%|          | 19/377110 [00:40<222:31:16,  2.12s/it]

# %%
len(get_images_info(metadata)) // 3
# Out:
# 125703
